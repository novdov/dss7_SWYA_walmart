# %% [markdown]
# # <font color='blue'>Classification Team Project</font>
# **Fast Campus Data Science School 7th Team B-2**

# %% [markdown]
# ## Walmart Recruiting: Trip Type Classification
# <img src="https://github.com/novdov/dss7_SWYA_walmart/blob/master/main/data/walmart.jpg?raw=true", width="700">

# %% [markdown]
# ### Overview
# - Team: Team B-2 SWYA (김선웅, 백윤아, 서원영)
# - Dataset: Walmart Shopping Records
# - Objective: Classification of each customers' TripType based on thier data
# - Evaluation: Multi-class log loss

# %% [markdown]
# ### Data Description:
#
# - train : 647054 rows, 7 columns
# - test : 653646 rows, 6 columns
#
# | Index | Feature               | Description                                  | Unique |
# |-------|-----------------------|----------------------------------------------|--------|
# | 1     | TripType              | A categorical id representing the type of shopping trip the customer made.                                       | 38     |
# | 2     | VisitNumber           | An id corresponding to a single trip by a single customer                              | 95674  |
# | 3     | Weekday               | The weekday of the trip                    | 7      |
# | 4     | Upc                   | The UPC number of the product purchased                  | 97715  |
# | 5     | ScanCount             | The number of the given item that was purchased. A negative value indicates a product return          | 39     |
# | 6     | DepartmentDescription | A high-level description of the item's department                                | 69     |
# | 7     | FinelineNumber        | A more refined category for each of the products, created by Walmart | 5196   |

# %% [markdown]
# ### UPC code description
# <img src="https://github.com/novdov/dss7_SWYA_walmart/blob/master/main/data/upc.png?raw=true", width="550">

# %% [markdown]
# ### Evaluation : Multi-class log loss (Cross Entropy)
#  $$-\frac{1}{N}\sum_{i=1}^N\sum_{j=1}^My_{ij}\log(p_{ij})$$
#
# - $N$ : the number of visits in the test set
# - $M$ : the number of trip types
# - $\log$ : natural logarithm
# - $y_{ij}$ : 1 if observation i is of class j and 0 otherwise
# - $p_{ij}$ : the predicted probability that observation i belongs to class j

# %% [markdown]
# ## Contents
#
# ### 1. EDA & Preprocessing
#
# ### 2. Feature Engineering
# - Feauture Engineering
#     - UPC decoding
#     - ScanCount seperation
#     - Feature encoding
#     - Dummy variables
#     - Identifing the most frequently purchased items per VisitNumber
#
# ### 3. Modeling (Random Forest and XGBoost)
# - Random Forest
# - XGBoost
#
# ### 4. Results
#
# ### 5. Kaggle Submission
# - Total Teams : 1,047 teams
# - Final Score : 0.79154
# - Leaderboard : 294/1,047 (top 30%)
#
# ### 6. Lesson

# %% [markdown]
# * * *

# %% [markdown]
# ## 1. EDA & Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %config InlineBackend.figure_formats = {'png', 'retina'}

from walmart_utils import *

train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
train.tail()
# Out:
#         TripType  VisitNumber Weekday           Upc  ScanCount  \
# 647049        39       191346  Sunday  3.239000e+10          1
# 647050        39       191346  Sunday  7.874205e+09          1
# 647051        39       191346  Sunday  4.072000e+03          1
# 647052         8       191347  Sunday  4.190008e+09          1
# 647053         8       191347  Sunday  3.800060e+09          1
#
#        DepartmentDescription  FinelineNumber
# 647049          PHARMACY OTC          1118.0
# 647050          FROZEN FOODS          1752.0
# 647051               PRODUCE          4170.0
# 647052                 DAIRY          1512.0
# 647053     GROCERY DRY GOODS          3600.0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647054 entries, 0 to 647053
# Data columns (total 7 columns):
# TripType                 647054 non-null int64
# VisitNumber              647054 non-null int64
# Weekday                  647054 non-null object
# Upc                      642925 non-null float64
# ScanCount                647054 non-null int64
# DepartmentDescription    645693 non-null object
# FinelineNumber           642925 non-null float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 34.6+ MB

# %% [markdown]
# ### Missing Values

# %%
plt.figure(figsize=(7, 5))
train.isnull().sum().plot(kind='bar', color="lightseagreen")
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# - Upc, DepartmentDescription, FinelineNumber에 Missing Values 존재
# - Upc와 FinelineNumber의 Missing Values는 동시에 나타남
# - Missing Value 제거 시 사라지는 VisitNumber 존재
# - Feature Engineering에서 VisitNumber에 대한 테이블로 변경
# - 최종 모델링 시 Nan은 0으로 처리

# %% [markdown]
# ### Encode Weekday (Labeling)

# %%
wd = {"Monday": 0, "Tuesday": 1, "Wednesday": 2, "Thursday": 3, 
      "Friday": 4, "Saturday": 5, "Sunday": 6}
train["Weekday"] = train["Weekday"].apply(lambda x: wd[x])
test["Weekday"] = test["Weekday"].apply(lambda x: wd[x])

# %%
plt.figure(figsize=(14, 3))

sns.heatmap(data=pd.crosstab(train["Weekday"],
                             train["TripType"], 
                             values=train["VisitNumber"],
                             aggfunc='count', 
                             normalize="columns"), cmap="RdPu")
plt.yticks(range(0,7), list(wd.keys()), rotation="horizontal")
plt.title("Distribution of Triptype on Weekday", fontsize=13)
plt.show()

# %% [markdown]
# - TripType 14는 월, 금/토에 많이 나타남
# - Feature에 반영 (One-Hot Encoding)

# %% [markdown]
# ### Uneven Distribution of TripType

# %%
plt.figure(figsize=(12, 5))

sns.set_style('whitegrid')
np.sort(train.TripType.unique())
train_triptypes = train.drop_duplicates("VisitNumber")
a = train_triptypes["TripType"]
a = a.value_counts()
a.plot(kind='bar', color="lightseagreen")
plt.title("Number of TripType Occurence by VisitNumber", fontsize=13)
plt.xlabel("TripType")

plt.show()

# %%
train_40 = train[train["TripType"]==40]
train_40["DepartmentDescription"].value_counts()[:10]
# Out:
# GROCERY DRY GOODS           32639
# DSD GROCERY                 22157
# DAIRY                       17354
# PRODUCE                     16704
# PERSONAL CARE                9911
# FROZEN FOODS                 9307
# HOUSEHOLD CHEMICALS/SUPP     8093
# COMM BREAD                   5968
# HOUSEHOLD PAPER GOODS        5712
# PHARMACY OTC                 4569
# Name: DepartmentDescription, dtype: int64

# %% [markdown]
# ### Most Frequent & Least Frequent TripType

# %%
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(121)
type_8 = train[train.TripType == 8]
type_8_items = type_8[["TripType","DepartmentDescription"]]
type_8_items.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                        title="TripType 8", color="seagreen")
ax1 = fig.add_subplot(122)
type_14 = train[train.TripType == 14]
type_14_items = type_14[["TripType","DepartmentDescription"]]
type_14_items.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                        title="TripType 14", color="lightcoral")

fig.suptitle("Distrubution of DepartmentDescription each TripType", fontsize=13)
plt.xticks(fontsize=10)
plt.show()

# %%
trip_desc = pd.crosstab(train["TripType"], 
                        train["DepartmentDescription"], 
                        values=train["ScanCount"], 
                        aggfunc="count", 
                        normalize="index")

plt.figure(figsize=(18, 9))
sns.heatmap(trip_desc, linecolor="lightgrey", linewidths=0.02, cmap="RdPu", alpha=.8)
plt.title("Distrubution of DepartmentDescription on TripTypes", fontsize=13)
plt.show()

# %% [markdown]
# - 비슷한 Department에서 물건 구매시 TripType 분류에 영향을 미치는 것으로 보임
# - 하나의 Department에서만 구매한 것이 아닌 여러 Department에서 구매함
# - 복수의 Department 방문 여부를 Feature에 반영 (CategoryCounts)

# %%
train_plot = train[["TripType", "ScanCount"]]
plot_grouped = train_plot.groupby("TripType", as_index=False).sum()

f, (ax, ax2) = plt.subplots(2, 1, sharex=True, figsize=(12, 5))
sns.barplot(x="TripType", y="ScanCount", data=plot_grouped, ax=ax)
sns.barplot(x="TripType", y="ScanCount", data=plot_grouped, ax=ax2)

ax.set_ylim(100000, 210000)
ax2.set_ylim(-2000, 2000)
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
ax2.yaxis.label.set_visible(False)

ax.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax.xaxis.tick_top()
ax.tick_params(labeltop='off') 
ax2.xaxis.tick_bottom()

d = .005

kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((-d, +d), (-d, +d), **kwargs)        
ax.plot((1 - d, 1 + d), (-d, +d), **kwargs)  

kwargs.update(transform=ax2.transAxes) 
ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)
ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs) 

f.text(0, 0.5, 'ScanCount', va='center', rotation='vertical', fontsize=11)
f.text(0.5, 1, 'ScanCount', va='center', rotation='horizontal', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# - TripType 999는 반품을 위한 방문이라고 생각됨
# - Return 여부를 Feature에 반영 (Return)
# - ScanCount를 실제 판매수량과 반품으로 나누어서 Feature에 반영 (Pos_Sum, Neg_Sum)

# %% [markdown]
# ## 2. Featuer Engineering

# %% [markdown]
# ### Decode company code from UPC

# %%
train["Upc"] = train.Upc.apply(float_to_str)
test["Upc"] = test.Upc.apply(float_to_str)

train["company"] = train.Upc.apply(company) 
test["company"] = test.Upc.apply(company)

# %% [markdown]
# ### Return Indicator

# %%
train.loc[train["ScanCount"] < 0, "Return"] = 1
train.loc[train["Return"] != 1, "Return"] = 0

test.loc[test["ScanCount"] < 0, "Return"] = 1
test.loc[test["Return"] != 1, "Return"] = 0

# %% [markdown]
# ### Positive ScanCount (The number of sold)

# %%
train["Pos_Sum"] = train["ScanCount"]
test["Pos_Sum"] = test["ScanCount"]

train.loc[train["Pos_Sum"] < 0, "Pos_Sum"] = 0
test.loc[test["Pos_Sum"] < 0, "Pos_Sum"] = 0

# %% [markdown]
# ### Negative ScanCount (The number of returns)

# %%
train["Neg_Sum"] = train["ScanCount"]
test["Neg_Sum"] = test["ScanCount"]

train.loc[train["Neg_Sum"] > 0, "Neg_Sum"] = 0
test.loc[test["Neg_Sum"] > 0, "Neg_Sum"] = 0

# %%
print(train.shape)
train.tail()
# Out:
# (647054, 11)
#         TripType  VisitNumber  Weekday          Upc  ScanCount  \
# 647049        39       191346        6  32390001778          1
# 647050        39       191346        6   7874205336          1
# 647051        39       191346        6         4072          1
# 647052         8       191347        6   4190007664          1
# 647053         8       191347        6   3800059655          1
#
#        DepartmentDescription  FinelineNumber company  Return  Pos_Sum  Neg_Sum
# 647049          PHARMACY OTC          1118.0  323900     0.0        1        0
# 647050          FROZEN FOODS          1752.0  787420     0.0        1        0
# 647051               PRODUCE          4170.0    4072     0.0        1        0
# 647052                 DAIRY          1512.0  419000     0.0        1        0
# 647053     GROCERY DRY GOODS          3600.0  380005     0.0        1        0

# %% [markdown]
# ### FinelineNumber most frequently appear

# %%
train_fineline = train[["VisitNumber", "FinelineNumber"]]
train_fineline = train_fineline.groupby("VisitNumber", as_index=False).agg(mode)
train_fineline.rename(columns={"FinelineNumber": "MF_FinelineNumber"}, inplace=True)

test_fineline = test[["VisitNumber", "FinelineNumber"]]
test_fineline = test_fineline.groupby("VisitNumber", as_index=False).agg(mode)
test_fineline.rename(columns={"FinelineNumber": "MF_FinelineNumber"}, inplace=True)

# %% [markdown]
# ### The number of UPC and  FinelineNumber for each VisitNumber

# %%
train_upc_fine = train[["VisitNumber", "Upc", "FinelineNumber"]]
test_upc_fine = test[["VisitNumber", "Upc", "FinelineNumber"]]

train_upc_fine_group = train_upc_fine.groupby("VisitNumber", as_index=False).count()
train_upc_fine_group.rename(columns={"Upc": "N_Upc", 
                                     "FinelineNumber": "N_FinelineNumber"}, inplace=True)
test_upc_fine_group = test_upc_fine.groupby("VisitNumber", as_index=False).count()
test_upc_fine_group.rename(columns={"Upc": "N_Upc", 
                                    "FinelineNumber": "N_FinelineNumber"}, inplace=True)

# %%
train.drop(["Upc", "FinelineNumber"], axis=1, inplace=True)
test.drop(["Upc", "FinelineNumber"], axis=1, inplace=True)

# %% [markdown]
# ### One-Hot Encoding of DepartmentDescription

# %%
train_dd = pd.get_dummies(train["DepartmentDescription"])
test_dd = pd.get_dummies(test["DepartmentDescription"])

train_dd = pd.concat([train[["VisitNumber"]], train_dd], axis=1)
test_dd = pd.concat([test[["VisitNumber"]], test_dd], axis=1)

train_dd = train_dd.groupby("VisitNumber", as_index=False).sum()
test_dd = test_dd.groupby("VisitNumber", as_index=False).sum()

# %%
train_dd.tail()
# Out:
#        VisitNumber  1-HR PHOTO  ACCESSORIES  AUTOMOTIVE  BAKERY  \
# 95669       191343           0            0           0       0
# 95670       191344           0            0           0       0
# 95671       191345           0            0           0       0
# 95672       191346           0            0           0       0
# 95673       191347           0            0           0       0
#
#        BATH AND SHOWER  BEAUTY  BEDDING  BOOKS AND MAGAZINES  BOYS WEAR  \
# 95669                0       0        0                    0          0
# 95670                0       4        0                    0          0
# 95671                0       1        0                    0          0
# 95672                0       0        0                    0          0
# 95673                0       0        0                    0          0
#
#          ...     SEAFOOD  SEASONAL  SERVICE DELI  SHEER HOSIERY  SHOES  \
# 95669    ...           0         0             0              0      0
# 95670    ...           0         0             0              0      0
# 95671    ...           0         0             0              0      0
# 95672    ...           0         0             0              0      0
# 95673    ...           0         0             0              0      0
#
#        SLEEPWEAR/FOUNDATIONS  SPORTING GOODS  SWIMWEAR/OUTERWEAR  TOYS  \
# 95669                      0               0                   0     0
# 95670                      0               0                   0     0
# 95671                      0               0                   0     0
# 95672                      0               0                   0     0
# 95673                      0               0                   0     0
#
#        WIRELESS
# 95669         0
# 95670         1
# 95671         0
# 95672         0
# 95673         0
#
# [5 rows x 69 columns]

# %% [markdown]
# ### FinelineNumber most frequently appear

# %%
train_company = train[["VisitNumber", "company"]]
test_company = test[["VisitNumber", "company"]]

train_company = train_company.groupby("VisitNumber", as_index=False).agg(mode)
test_company = test_company.groupby("VisitNumber", as_index=False).agg(mode)

# %% [markdown]
# ### Pivot data by VisitNumber

# %%
train_by_sum = train[["VisitNumber", "ScanCount", "Pos_Sum", "Neg_Sum"]]
test_by_sum = test[["VisitNumber", "ScanCount", "Pos_Sum", "Neg_Sum"]]

train_by_sum = train_by_sum.groupby("VisitNumber", as_index=False).sum()
test_by_sum = test_by_sum.groupby("VisitNumber", as_index=False).sum()

train_by_max = train[["TripType", "VisitNumber", "Weekday", "Return"]]
test_by_max = test[["VisitNumber", "Weekday", "Return"]]

train_by_max = train_by_max.groupby("VisitNumber", as_index=False).max()
test_by_max = test_by_max.groupby("VisitNumber", as_index=False).max()

# %%
train = train_by_sum.merge(train_by_max, on=["VisitNumber"])
train = train.merge(train_dd, on=["VisitNumber"])
train = train.merge(train_company, on=["VisitNumber"])
train = train.merge(train_fineline, on=["VisitNumber"])
train = train.merge(train_upc_fine_group, on=["VisitNumber"])

test = test_by_sum.merge(test_by_max, on=["VisitNumber"])
test = test.merge(test_dd, on=["VisitNumber"])
test = test.merge(test_company, on=["VisitNumber"])
test = test.merge(test_fineline, on=["VisitNumber"])
test = test.merge(test_upc_fine_group, on=["VisitNumber"])

# %% [markdown]
# - Remove DepartmentDescription not shown in test data
# - Segregate features & target

# %%
y = train["TripType"]
train = train.drop(["TripType", "HEALTH AND BEAUTY AIDS"], axis=1)

# %% [markdown]
# ### The counts of DepartmentDescription for each VistNumber

# %%
# from walmart_utils import category_counts
# %time train = category_counts(train)
# %time test = category_counts(test)
# Out:
# CPU times: user 8.49 s, sys: 11.3 ms, total: 8.5 s
# Wall time: 8.51 s
# CPU times: user 8.33 s, sys: 9.99 ms, total: 8.34 s
# Wall time: 8.34 s

# %% [markdown]
# ### Ratio of number of UPC and FinelineNumber

# %%
train["Upc_FLN"] = train["N_Upc"] / train["N_FinelineNumber"]
test["Upc_FLN"] = test["N_Upc"] / test["N_FinelineNumber"]

# %% [markdown]
# ### One-Hot Encoding of Weeday and Return

# %%
train = pd.get_dummies(train, columns=["Weekday", "Return", "MF_DepartmentDescription"])
test = pd.get_dummies(test, columns=["Weekday", "Return", "MF_DepartmentDescription"])

# %%
vn = test[["VisitNumber"]]
train.drop("VisitNumber", axis=1, inplace=True)
test.drop("VisitNumber", axis=1, inplace=True)

# %% [markdown]
# ### Replace Null Value, Inf Value with 0

# %%
train.replace(np.inf, 0, inplace=True)
train.fillna(value=0, inplace=True)

test.replace(np.inf, 0, inplace=True)
test.fillna(value=0, inplace=True)

# %% [markdown]
# ### Final Data
# - 86 features

# %%
train.tail()
# Out:
#        ScanCount  Pos_Sum  Neg_Sum  CategoryCounts  1-HR PHOTO  ACCESSORIES  \
# 95669          9        9        0               3           0            0
# 95670          5        5        0               2           0            0
# 95671         17       17        0               8           0            0
# 95672         17       17        0               8           0            0
# 95673          2        2        0               2           0            0
#
#        AUTOMOTIVE  BAKERY  BATH AND SHOWER  BEAUTY  \
# 95669           0       0                0       0
# 95670           0       0                0       4
# 95671           0       0                0       1
# 95672           0       0                0       0
# 95673           0       0                0       0
#
#                      ...                  MF_DepartmentDescription_SEAFOOD  \
# 95669                ...                                                 0
# 95670                ...                                                 0
# 95671                ...                                                 0
# 95672                ...                                                 0
# 95673                ...                                                 0
#
#        MF_DepartmentDescription_SEASONAL  \
# 95669                                  0
# 95670                                  0
# 95671                                  0
# 95672                                  0
# 95673                                  0
#
#        MF_DepartmentDescription_SERVICE DELI  \
# 95669                                      0
# 95670                                      0
# 95671                                      0
# 95672                                      0
# 95673                                      0
#
#        MF_DepartmentDescription_SHEER HOSIERY  MF_DepartmentDescription_SHOES  \
# 95669                                       0                               0
# 95670                                       0                               0
# 95671                                       0                               0
# 95672                                       0                               0
# 95673                                       0                               0
#
#        MF_DepartmentDescription_SLEEPWEAR/FOUNDATIONS  \
# 95669                                               0
# 95670                                               0
# 95671                                               0
# 95672                                               0
# 95673                                               0
#
#        MF_DepartmentDescription_SPORTING GOODS  \
# 95669                                        0
# 95670                                        0
# 95671                                        0
# 95672                                        0
# 95673                                        0
#
#        MF_DepartmentDescription_SWIMWEAR/OUTERWEAR  \
# 95669                                            0
# 95670                                            0
# 95671                                            0
# 95672                                            0
# 95673                                            0
#
#        MF_DepartmentDescription_TOYS  MF_DepartmentDescription_WIRELESS
# 95669                              0                                  0
# 95670                              0                                  0
# 95671                              0                                  0
# 95672                              0                                  0
# 95673                              0                                  0
#
# [5 rows x 154 columns]

# %% [markdown]
# * * *

# %% [markdown]
# ## 3. Modeling
#
# - Random Forest
# - XGBoost

# %% [markdown]
# ### Final Features (Total 86)

# %% [markdown]
# - ScanCount
# - Return (dummies)
# - Pos_Sum
# - Neg_Sum
# - CategoryCounts
# - DepartmentDescription (dummies)
# - Company code
# - MF_Fineline (Most Frequent FinelineNumbers)
# - MF_DepartmentDescription (Most Frequent DepartmentDescription)
# - N_UPC (The number of UPC
# - N_FinelineNumber (The number of FinelineNumber)
# - UPC_FLN (N_UPC / N_FinelineNumber)
# - Weekday (dummies)

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
label_enc = LabelEncoder().fit(y)
y_labeled = label_enc.transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    train, y_labeled, random_state=0)

# %%
dtrain = xgb.DMatrix(X_train.values, label=y_train)
dtest = xgb.DMatrix(X_test.values, label=y_test)

# %%
num_boost_round = 300
params = {'objective': 'multi:softprob', 
          'eval_metric': 'mlogloss',
          'num_class':38, 
          'max_delta_step': 3, 
          'eta': 0.2}

evals = [(dtrain, 'train'), (dtest, 'eval')]

bst = xgb.train(params=params,  
                dtrain=dtrain, 
                num_boost_round=num_boost_round, 
                evals=evals,
                early_stopping_rounds=10,)
# Out:
# [0]	train-mlogloss:3.07295	eval-mlogloss:3.08218
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# Will train until eval-mlogloss hasn't improved in 10 rounds.
# [1]	train-mlogloss:2.57164	eval-mlogloss:2.59177
# [2]	train-mlogloss:2.17018	eval-mlogloss:2.2036
# [3]	train-mlogloss:1.87296	eval-mlogloss:1.91539
# [4]	train-mlogloss:1.67639	eval-mlogloss:1.72582
# [5]	train-mlogloss:1.52843	eval-mlogloss:1.58453
# [6]	train-mlogloss:1.41329	eval-mlogloss:1.47551
# [7]	train-mlogloss:1.31861	eval-mlogloss:1.38702
# [8]	train-mlogloss:1.24043	eval-mlogloss:1.31458
# [9]	train-mlogloss:1.17416	eval-mlogloss:1.25374
# [10]	train-mlogloss:1.11823	eval-mlogloss:1.20231
# [11]	train-mlogloss:1.06992	eval-mlogloss:1.1589
# [12]	train-mlogloss:1.02704	eval-mlogloss:1.12072
# [13]	train-mlogloss:0.990042	eval-mlogloss:1.08826
# [14]	train-mlogloss:0.957684	eval-mlogloss:1.06011
# [15]	train-mlogloss:0.929533	eval-mlogloss:1.03638
# [16]	train-mlogloss:0.903919	eval-mlogloss:1.01477
# [17]	train-mlogloss:0.880977	eval-mlogloss:0.996288
# [18]	train-mlogloss:0.860673	eval-mlogloss:0.979863
# [19]	train-mlogloss:0.841607	eval-mlogloss:0.964644
# [20]	train-mlogloss:0.824502	eval-mlogloss:0.951258
# [21]	train-mlogloss:0.809355	eval-mlogloss:0.939509
# [22]	train-mlogloss:0.794514	eval-mlogloss:0.928638
# [23]	train-mlogloss:0.781021	eval-mlogloss:0.919016
# [24]	train-mlogloss:0.768852	eval-mlogloss:0.910343
# [25]	train-mlogloss:0.756328	eval-mlogloss:0.901093
# [26]	train-mlogloss:0.745557	eval-mlogloss:0.894151
# [27]	train-mlogloss:0.73488	eval-mlogloss:0.887008
# [28]	train-mlogloss:0.725509	eval-mlogloss:0.881081
# [29]	train-mlogloss:0.716596	eval-mlogloss:0.875695
# [30]	train-mlogloss:0.707845	eval-mlogloss:0.870382
# [31]	train-mlogloss:0.700038	eval-mlogloss:0.866198
# [32]	train-mlogloss:0.692916	eval-mlogloss:0.861984
# [33]	train-mlogloss:0.685857	eval-mlogloss:0.858138
# [34]	train-mlogloss:0.678765	eval-mlogloss:0.854136
# [35]	train-mlogloss:0.671937	eval-mlogloss:0.850113
# [36]	train-mlogloss:0.665919	eval-mlogloss:0.847257
# [37]	train-mlogloss:0.660376	eval-mlogloss:0.844411
# [38]	train-mlogloss:0.654467	eval-mlogloss:0.841633
# [39]	train-mlogloss:0.648543	eval-mlogloss:0.838962
# [40]	train-mlogloss:0.643583	eval-mlogloss:0.836488
# [41]	train-mlogloss:0.638774	eval-mlogloss:0.833921
# [42]	train-mlogloss:0.633806	eval-mlogloss:0.831615
# [43]	train-mlogloss:0.629489	eval-mlogloss:0.829937
# [44]	train-mlogloss:0.62531	eval-mlogloss:0.827976
# [45]	train-mlogloss:0.62098	eval-mlogloss:0.82619
# [46]	train-mlogloss:0.616813	eval-mlogloss:0.824318
# [47]	train-mlogloss:0.611984	eval-mlogloss:0.822339
# [48]	train-mlogloss:0.608097	eval-mlogloss:0.820698
# [49]	train-mlogloss:0.604488	eval-mlogloss:0.819472
# [50]	train-mlogloss:0.600304	eval-mlogloss:0.817712
# [51]	train-mlogloss:0.596826	eval-mlogloss:0.816383
# [52]	train-mlogloss:0.593182	eval-mlogloss:0.815067
# [53]	train-mlogloss:0.589334	eval-mlogloss:0.813765
# [54]	train-mlogloss:0.585766	eval-mlogloss:0.812494
# [55]	train-mlogloss:0.582683	eval-mlogloss:0.811529
# [56]	train-mlogloss:0.579217	eval-mlogloss:0.81062
# [57]	train-mlogloss:0.576485	eval-mlogloss:0.809855
# [58]	train-mlogloss:0.573285	eval-mlogloss:0.809169
# [59]	train-mlogloss:0.569984	eval-mlogloss:0.808179
# [60]	train-mlogloss:0.56716	eval-mlogloss:0.807348
# [61]	train-mlogloss:0.56423	eval-mlogloss:0.806467
# [62]	train-mlogloss:0.561248	eval-mlogloss:0.805605
# [63]	train-mlogloss:0.558735	eval-mlogloss:0.804891
# [64]	train-mlogloss:0.555882	eval-mlogloss:0.804297
# [65]	train-mlogloss:0.553516	eval-mlogloss:0.803772
# [66]	train-mlogloss:0.550835	eval-mlogloss:0.802799
# [67]	train-mlogloss:0.548652	eval-mlogloss:0.802009
# [68]	train-mlogloss:0.545954	eval-mlogloss:0.801299
# [69]	train-mlogloss:0.543415	eval-mlogloss:0.800562
# [70]	train-mlogloss:0.540724	eval-mlogloss:0.799583
# [71]	train-mlogloss:0.538068	eval-mlogloss:0.798672
# [72]	train-mlogloss:0.535508	eval-mlogloss:0.797939
# [73]	train-mlogloss:0.533138	eval-mlogloss:0.797413
# [74]	train-mlogloss:0.530673	eval-mlogloss:0.796969
# [75]	train-mlogloss:0.528761	eval-mlogloss:0.796643
# [76]	train-mlogloss:0.526578	eval-mlogloss:0.796131
# [77]	train-mlogloss:0.524597	eval-mlogloss:0.795708
# [78]	train-mlogloss:0.522223	eval-mlogloss:0.795411
# [79]	train-mlogloss:0.519628	eval-mlogloss:0.794658
# [80]	train-mlogloss:0.517414	eval-mlogloss:0.794056
# [81]	train-mlogloss:0.515665	eval-mlogloss:0.793612
# [82]	train-mlogloss:0.513524	eval-mlogloss:0.793375
# [83]	train-mlogloss:0.511364	eval-mlogloss:0.792798
# [84]	train-mlogloss:0.509035	eval-mlogloss:0.792353
# [85]	train-mlogloss:0.506924	eval-mlogloss:0.791852
# [86]	train-mlogloss:0.504958	eval-mlogloss:0.791629
# [87]	train-mlogloss:0.502934	eval-mlogloss:0.791294
# [88]	train-mlogloss:0.501034	eval-mlogloss:0.79096
# [89]	train-mlogloss:0.499016	eval-mlogloss:0.790668
# [90]	train-mlogloss:0.497199	eval-mlogloss:0.790404
# [91]	train-mlogloss:0.495263	eval-mlogloss:0.790145
# [92]	train-mlogloss:0.493428	eval-mlogloss:0.789679
# [93]	train-mlogloss:0.491633	eval-mlogloss:0.789438
# [94]	train-mlogloss:0.489648	eval-mlogloss:0.789158
# [95]	train-mlogloss:0.488145	eval-mlogloss:0.788772
# [96]	train-mlogloss:0.486404	eval-mlogloss:0.788509
# [97]	train-mlogloss:0.484769	eval-mlogloss:0.788288
# [98]	train-mlogloss:0.483246	eval-mlogloss:0.78821
# [99]	train-mlogloss:0.481161	eval-mlogloss:0.78787
# [100]	train-mlogloss:0.479324	eval-mlogloss:0.787616
# [101]	train-mlogloss:0.477741	eval-mlogloss:0.787341
# [102]	train-mlogloss:0.475927	eval-mlogloss:0.787004
# [103]	train-mlogloss:0.474287	eval-mlogloss:0.786841
# [104]	train-mlogloss:0.472417	eval-mlogloss:0.786709
# [105]	train-mlogloss:0.471049	eval-mlogloss:0.786471
# [106]	train-mlogloss:0.469396	eval-mlogloss:0.786261
# [107]	train-mlogloss:0.467391	eval-mlogloss:0.785986
# [108]	train-mlogloss:0.465556	eval-mlogloss:0.785875
# [109]	train-mlogloss:0.463882	eval-mlogloss:0.785693
# [110]	train-mlogloss:0.462041	eval-mlogloss:0.785523
# [111]	train-mlogloss:0.460271	eval-mlogloss:0.785386
# [112]	train-mlogloss:0.458726	eval-mlogloss:0.785212
# [113]	train-mlogloss:0.457119	eval-mlogloss:0.785256
# [114]	train-mlogloss:0.455554	eval-mlogloss:0.785089
# [115]	train-mlogloss:0.453801	eval-mlogloss:0.784644
# [116]	train-mlogloss:0.452149	eval-mlogloss:0.784716
# [117]	train-mlogloss:0.450446	eval-mlogloss:0.784376
# [118]	train-mlogloss:0.448792	eval-mlogloss:0.784325
# [119]	train-mlogloss:0.447385	eval-mlogloss:0.784114
# [120]	train-mlogloss:0.446066	eval-mlogloss:0.783886
# [121]	train-mlogloss:0.444511	eval-mlogloss:0.783975
# [122]	train-mlogloss:0.442924	eval-mlogloss:0.783889
# [123]	train-mlogloss:0.441391	eval-mlogloss:0.783676
# [124]	train-mlogloss:0.439737	eval-mlogloss:0.783697
# [125]	train-mlogloss:0.438247	eval-mlogloss:0.78359
# [126]	train-mlogloss:0.436993	eval-mlogloss:0.783676
# [127]	train-mlogloss:0.435547	eval-mlogloss:0.783604
# [128]	train-mlogloss:0.434192	eval-mlogloss:0.78347
# [129]	train-mlogloss:0.432494	eval-mlogloss:0.783505
# [130]	train-mlogloss:0.430874	eval-mlogloss:0.783396
# [131]	train-mlogloss:0.429521	eval-mlogloss:0.783239
# [132]	train-mlogloss:0.42792	eval-mlogloss:0.782987
# [133]	train-mlogloss:0.426189	eval-mlogloss:0.782772
# [134]	train-mlogloss:0.424581	eval-mlogloss:0.782505
# [135]	train-mlogloss:0.423287	eval-mlogloss:0.782507
# [136]	train-mlogloss:0.421971	eval-mlogloss:0.782549
# [137]	train-mlogloss:0.420556	eval-mlogloss:0.782678
# [138]	train-mlogloss:0.419249	eval-mlogloss:0.782604
# [139]	train-mlogloss:0.417946	eval-mlogloss:0.782682
# [140]	train-mlogloss:0.416461	eval-mlogloss:0.782753
# [141]	train-mlogloss:0.415193	eval-mlogloss:0.78253
# [142]	train-mlogloss:0.413961	eval-mlogloss:0.78243
# [143]	train-mlogloss:0.412819	eval-mlogloss:0.782465
# [144]	train-mlogloss:0.411646	eval-mlogloss:0.782428
# [145]	train-mlogloss:0.410115	eval-mlogloss:0.78218
# [146]	train-mlogloss:0.408635	eval-mlogloss:0.782153
# [147]	train-mlogloss:0.40735	eval-mlogloss:0.782177
# [148]	train-mlogloss:0.406041	eval-mlogloss:0.782262
# [149]	train-mlogloss:0.404645	eval-mlogloss:0.782102
# [150]	train-mlogloss:0.403127	eval-mlogloss:0.782253
# [151]	train-mlogloss:0.401637	eval-mlogloss:0.782073
# [152]	train-mlogloss:0.400311	eval-mlogloss:0.782031
# [153]	train-mlogloss:0.399341	eval-mlogloss:0.782003
# [154]	train-mlogloss:0.398022	eval-mlogloss:0.782032
# [155]	train-mlogloss:0.396035	eval-mlogloss:0.781884
# [156]	train-mlogloss:0.394652	eval-mlogloss:0.781909
# [157]	train-mlogloss:0.393307	eval-mlogloss:0.781885
# [158]	train-mlogloss:0.392108	eval-mlogloss:0.781844
# [159]	train-mlogloss:0.39104	eval-mlogloss:0.781879
# [160]	train-mlogloss:0.389667	eval-mlogloss:0.781767
# [161]	train-mlogloss:0.388478	eval-mlogloss:0.781697
# [162]	train-mlogloss:0.387195	eval-mlogloss:0.781714
# [163]	train-mlogloss:0.385982	eval-mlogloss:0.781793
# [164]	train-mlogloss:0.384736	eval-mlogloss:0.781596
# [165]	train-mlogloss:0.383621	eval-mlogloss:0.78169
# [166]	train-mlogloss:0.38242	eval-mlogloss:0.781675
# [167]	train-mlogloss:0.38096	eval-mlogloss:0.781543
# [168]	train-mlogloss:0.379627	eval-mlogloss:0.781712
# [169]	train-mlogloss:0.378394	eval-mlogloss:0.781837
# [170]	train-mlogloss:0.376918	eval-mlogloss:0.781782
# [171]	train-mlogloss:0.375667	eval-mlogloss:0.781747
# [172]	train-mlogloss:0.374691	eval-mlogloss:0.781904
# [173]	train-mlogloss:0.373491	eval-mlogloss:0.782141
# [174]	train-mlogloss:0.372258	eval-mlogloss:0.782155
# [175]	train-mlogloss:0.370898	eval-mlogloss:0.782319
# [176]	train-mlogloss:0.369875	eval-mlogloss:0.782384
# [177]	train-mlogloss:0.368922	eval-mlogloss:0.78259
# Stopping. Best iteration:
# [167]	train-mlogloss:0.38096	eval-mlogloss:0.781543

# %% [markdown]
# ##### logarithmic loss

# %%
from sklearn.metrics import log_loss
my_test = xgb.DMatrix(X_test.values)
test_predictions = bst.predict(my_test)
print("log loss :", log_loss(y_test, test_predictions).round(5))
# Out:
# log loss : 0.78259

# %% [markdown]
# #### *Featue Importance*

# %%
import operator
importance_dict = bst.get_score()
sorted_dict = sorted(importance_dict.items(), key=operator.itemgetter(1))
sorted_dict = sorted_dict[::-1]

indices = []
for i in range(len(sorted_dict)-1):
    indices.append(sorted_dict[i][0])
    
indices = [int(idx[1:]) for idx in indices]

importance_features = []
for idx in indices:
    importance_features.append(train.columns[idx])

importance = list(bst.get_score().values())
importance = sorted(importance)
importance = importance[::-1]

pairs = list(zip(importance, importance_features))
labels = [label[1] for label in pairs]

plt.figure(figsize=(12, 8))
plt.barh(range(20), importance[:20][::-1], align="center")
plt.yticks(np.arange(20), labels[:20][::-1])
plt.xlabel("Feature importance")
plt.ylim(-1, 20)
plt.show()

# %% [markdown]
# ##### Accuracy score

# %%
yprob = test_predictions.reshape(y_test.shape[0], 38)
ylabel = np.argmax(yprob, axis=1)
accuracy = 100 *(1 - (sum(int(ylabel[i]) != y_test[i]
                         for i in range(len(y_test))) / float(len(y_test))))
print("TripType Accuracy = %.2f%%" % accuracy)
# Out:
# TripType Accuracy = 73.68%

# %% [markdown]
# #### *Submission*

# %%
classes = np.array(list(set(label_enc.inverse_transform(y_labeled))))

dmtest = xgb.DMatrix(test.values) 
pred_proba = bst.predict(dmtest)

proba_df = pd.DataFrame(pred_proba, columns=classes)
proba_df.columns = proba_df.columns.map(lambda x: "TripType_" + str(x))
sub_df = pd.concat([vn, proba_df], axis=1)
sub_df.to_csv("../../team_SWYA_submission.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-185-f6bc2bc5acd9> in <module>()
#       2
#       3 dmtest = xgb.DMatrix(test.values)
# ----> 4 pred_proba = bst.predict(dmtest)
#       5
#       6 proba_df = pd.DataFrame(pred_proba, columns=classes)
#
# ~/xgboost/python-package/xgboost/core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs, pred_interactions)
#    1048             option_mask |= 0x10
#    1049
# -> 1050         self._validate_features(data)
#    1051
#    1052         length = c_bst_ulong()
#
# ~/xgboost/python-package/xgboost/core.py in _validate_features(self, data)
#    1306
#    1307                 raise ValueError(msg.format(self.feature_names,
# -> 1308                                             data.feature_names))
#    1309
#    1310     def get_split_value_histogram(self, feature, fmap='', bins=None, as_pandas=True):
#
# ValueError: feature_names mismatch: ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29', 'f30', 'f31', 'f32', 'f33', 'f34', 'f35', 'f36', 'f37', 'f38', 'f39', 'f40', 'f41', 'f42', 'f43', 'f44', 'f45', 'f46', 'f47', 'f48', 'f49', 'f50', 'f51', 'f52', 'f53', 'f54', 'f55', 'f56', 'f57', 'f58', 'f59', 'f60', 'f61', 'f62', 'f63', 'f64', 'f65', 'f66', 'f67', 'f68', 'f69', 'f70', 'f71', 'f72', 'f73', 'f74', 'f75', 'f76', 'f77', 'f78', 'f79', 'f80', 'f81', 'f82', 'f83', 'f84', 'f85', 'f86', 'f87', 'f88', 'f89', 'f90', 'f91', 'f92', 'f93', 'f94', 'f95', 'f96', 'f97', 'f98', 'f99', 'f100', 'f101', 'f102', 'f103', 'f104', 'f105', 'f106', 'f107', 'f108', 'f109', 'f110', 'f111', 'f112', 'f113', 'f114', 'f115', 'f116', 'f117', 'f118', 'f119', 'f120', 'f121', 'f122', 'f123', 'f124', 'f125', 'f126', 'f127', 'f128', 'f129', 'f130', 'f131', 'f132', 'f133', 'f134', 'f135', 'f136', 'f137', 'f138', 'f139', 'f140', 'f141', 'f142', 'f143', 'f144', 'f145', 'f146', 'f147', 'f148', 'f149', 'f150', 'f151', 'f152', 'f153'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29', 'f30', 'f31', 'f32', 'f33', 'f34', 'f35', 'f36', 'f37', 'f38', 'f39', 'f40', 'f41', 'f42', 'f43', 'f44', 'f45', 'f46', 'f47', 'f48', 'f49', 'f50', 'f51', 'f52', 'f53', 'f54', 'f55', 'f56', 'f57', 'f58', 'f59', 'f60', 'f61', 'f62', 'f63', 'f64', 'f65', 'f66', 'f67', 'f68', 'f69', 'f70', 'f71', 'f72', 'f73', 'f74', 'f75', 'f76', 'f77', 'f78', 'f79', 'f80', 'f81', 'f82', 'f83', 'f84', 'f85', 'f86', 'f87', 'f88', 'f89', 'f90', 'f91', 'f92', 'f93', 'f94', 'f95', 'f96', 'f97', 'f98', 'f99', 'f100', 'f101', 'f102', 'f103', 'f104', 'f105', 'f106', 'f107', 'f108', 'f109', 'f110', 'f111', 'f112', 'f113', 'f114', 'f115', 'f116', 'f117', 'f118', 'f119', 'f120', 'f121', 'f122', 'f123', 'f124', 'f125', 'f126', 'f127', 'f128', 'f129', 'f130', 'f131', 'f132', 'f133', 'f134', 'f135', 'f136', 'f137', 'f138', 'f139', 'f140', 'f141', 'f142', 'f143', 'f144', 'f145', 'f146', 'f147', 'f148', 'f149', 'f150', 'f151', 'f152']
# expected f153 in input data

# %% [markdown]
# <img src="https://github.com/yunah0515/dss7_SWYA_walmart/blob/master/2%ED%8C%80(SWYA)_B/data/final_score.png?raw=true">
